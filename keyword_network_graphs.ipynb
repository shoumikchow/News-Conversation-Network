# %%
import networkx as nx
import math
import matplotlib.pyplot as plt

# %%
all_combos_dict = {('attack', 'authority'): 394,
 ('attack', 'bnp'): 0,
 ('attack', 'buddhist'): 1,
 ('attack', 'celebration'): 198,
 ('attack', 'christian'): 0,
 ('attack', 'eid'): 121,
 ('attack', 'ethnic'): 600,
 ('attack', 'hindu'): 1,
 ('attack', 'holidays'): 53,
 ('attack', 'jamaat'): 4,
 ('attack', 'league'): 719,
 ('attack', 'minority'): 531,
 ('attack', 'muslim'): 5,
 ('attack', 'nationalist'): 207,
 ('attack', 'opposition'): 1540,
 ('attack', 'pakistan'): 0,
 ('attack', 'police'): 6437,
 ('attack', 'puja'): 17,
 ('attack', 'rape'): 450,
 ('attack', 'shibir'): 13,
 ('attack', 'vandalism'): 182,
 ('authority', 'bnp'): 0,
 ('authority', 'buddhist'): 1,
 ('authority', 'celebration'): 63,
 ('authority', 'christian'): 0,
 ('authority', 'eid'): 27,
 ('authority', 'ethnic'): 67,
 ('authority', 'hindu'): 1,
 ('authority', 'holidays'): 32,
 ('authority', 'jamaat'): 1,
 ('authority', 'league'): 114,
 ('authority', 'minority'): 68,
 ('authority', 'muslim'): 0,
 ('authority', 'nationalist'): 32,
 ('authority', 'opposition'): 290,
 ('authority', 'pakistan'): 0,
 ('authority', 'police'): 527,
 ('authority', 'puja'): 5,
 ('authority', 'rape'): 71,
 ('authority', 'shibir'): 0,
 ('authority', 'vandalism'): 8,
 ('bnp', 'buddhist'): 0,
 ('bnp', 'celebration'): 0,
 ('bnp', 'christian'): 0,
 ('bnp', 'eid'): 0,
 ('bnp', 'ethnic'): 0,
 ('bnp', 'hindu'): 0,
 ('bnp', 'holidays'): 0,
 ('bnp', 'jamaat'): 0,
 ('bnp', 'league'): 0,
 ('bnp', 'minority'): 0,
 ('bnp', 'muslim'): 0,
 ('bnp', 'nationalist'): 0,
 ('bnp', 'opposition'): 0,
 ('bnp', 'pakistan'): 0,
 ('bnp', 'police'): 0,
 ('bnp', 'puja'): 0,
 ('bnp', 'rape'): 0,
 ('bnp', 'shibir'): 0,
 ('bnp', 'vandalism'): 0,
 ('buddhist', 'celebration'): 0,
 ('buddhist', 'christian'): 0,
 ('buddhist', 'eid'): 0,
 ('buddhist', 'ethnic'): 1,
 ('buddhist', 'hindu'): 0,
 ('buddhist', 'holidays'): 0,
 ('buddhist', 'jamaat'): 0,
 ('buddhist', 'league'): 1,
 ('buddhist', 'minority'): 1,
 ('buddhist', 'muslim'): 0,
 ('buddhist', 'nationalist'): 0,
 ('buddhist', 'opposition'): 0,
 ('buddhist', 'pakistan'): 0,
 ('buddhist', 'police'): 0,
 ('buddhist', 'puja'): 0,
 ('buddhist', 'rape'): 0,
 ('buddhist', 'shibir'): 0,
 ('buddhist', 'vandalism'): 0,
 ('celebration', 'christian'): 0,
 ('celebration', 'eid'): 36,
 ('celebration', 'ethnic'): 79,
 ('celebration', 'hindu'): 3,
 ('celebration', 'holidays'): 33,
 ('celebration', 'jamaat'): 2,
 ('celebration', 'league'): 97,
 ('celebration', 'minority'): 41,
 ('celebration', 'muslim'): 1,
 ('celebration', 'nationalist'): 32,
 ('celebration', 'opposition'): 85,
 ('celebration', 'pakistan'): 0,
 ('celebration', 'police'): 189,
 ('celebration', 'puja'): 55,
 ('celebration', 'rape'): 55,
 ('celebration', 'shibir'): 0,
 ('celebration', 'vandalism'): 3,
 ('christian', 'eid'): 0,
 ('christian', 'ethnic'): 0,
 ('christian', 'hindu'): 0,
 ('christian', 'holidays'): 0,
 ('christian', 'jamaat'): 0,
 ('christian', 'league'): 0,
 ('christian', 'minority'): 0,
 ('christian', 'muslim'): 0,
 ('christian', 'nationalist'): 0,
 ('christian', 'opposition'): 0,
 ('christian', 'pakistan'): 0,
 ('christian', 'police'): 0,
 ('christian', 'puja'): 0,
 ('christian', 'rape'): 0,
 ('christian', 'shibir'): 0,
 ('christian', 'vandalism'): 0,
 ('eid', 'ethnic'): 44,
 ('eid', 'hindu'): 0,
 ('eid', 'holidays'): 9,
 ('eid', 'jamaat'): 2,
 ('eid', 'league'): 52,
 ('eid', 'minority'): 44,
 ('eid', 'muslim'): 0,
 ('eid', 'nationalist'): 14,
 ('eid', 'opposition'): 70,
 ('eid', 'pakistan'): 0,
 ('eid', 'police'): 91,
 ('eid', 'puja'): 0,
 ('eid', 'rape'): 27,
 ('eid', 'shibir'): 0,
 ('eid', 'vandalism'): 0,
 ('ethnic', 'hindu'): 1,
 ('ethnic', 'holidays'): 9,
 ('ethnic', 'jamaat'): 0,
 ('ethnic', 'league'): 43,
 ('ethnic', 'minority'): 510,
 ('ethnic', 'muslim'): 0,
 ('ethnic', 'nationalist'): 76,
 ('ethnic', 'opposition'): 267,
 ('ethnic', 'pakistan'): 1,
 ('ethnic', 'police'): 479,
 ('ethnic', 'puja'): 7,
 ('ethnic', 'rape'): 125,
 ('ethnic', 'shibir'): 0,
 ('ethnic', 'vandalism'): 8,
 ('hindu', 'holidays'): 0,
 ('hindu', 'jamaat'): 0,
 ('hindu', 'league'): 0,
 ('hindu', 'minority'): 0,
 ('hindu', 'muslim'): 1,
 ('hindu', 'nationalist'): 0,
 ('hindu', 'opposition'): 1,
 ('hindu', 'pakistan'): 0,
 ('hindu', 'police'): 2,
 ('hindu', 'puja'): 2,
 ('hindu', 'rape'): 0,
 ('hindu', 'shibir'): 0,
 ('hindu', 'vandalism'): 0,
 ('holidays', 'jamaat'): 0,
 ('holidays', 'league'): 33,
 ('holidays', 'minority'): 4,
 ('holidays', 'muslim'): 0,
 ('holidays', 'nationalist'): 2,
 ('holidays', 'opposition'): 21,
 ('holidays', 'pakistan'): 0,
 ('holidays', 'police'): 95,
 ('holidays', 'puja'): 6,
 ('holidays', 'rape'): 13,
 ('holidays', 'shibir'): 0,
 ('holidays', 'vandalism'): 5,
 ('jamaat', 'league'): 0,
 ('jamaat', 'minority'): 0,
 ('jamaat', 'muslim'): 0,
 ('jamaat', 'nationalist'): 0,
 ('jamaat', 'opposition'): 2,
 ('jamaat', 'pakistan'): 0,
 ('jamaat', 'police'): 10,
 ('jamaat', 'puja'): 0,
 ('jamaat', 'rape'): 0,
 ('jamaat', 'shibir'): 2,
 ('jamaat', 'vandalism'): 1,
 ('league', 'minority'): 59,
 ('league', 'muslim'): 1,
 ('league', 'nationalist'): 36,
 ('league', 'opposition'): 324,
 ('league', 'pakistan'): 0,
 ('league', 'police'): 547,
 ('league', 'puja'): 2,
 ('league', 'rape'): 108,
 ('league', 'shibir'): 0,
 ('league', 'vandalism'): 15,
 ('minority', 'muslim'): 1,
 ('minority', 'nationalist'): 58,
 ('minority', 'opposition'): 282,
 ('minority', 'pakistan'): 0,
 ('minority', 'police'): 386,
 ('minority', 'puja'): 2,
 ('minority', 'rape'): 99,
 ('minority', 'shibir'): 0,
 ('minority', 'vandalism'): 12,
 ('muslim', 'nationalist'): 0,
 ('muslim', 'opposition'): 0,
 ('muslim', 'pakistan'): 0,
 ('muslim', 'police'): 2,
 ('muslim', 'puja'): 0,
 ('muslim', 'rape'): 0,
 ('muslim', 'shibir'): 0,
 ('muslim', 'vandalism'): 0,
 ('nationalist', 'opposition'): 216,
 ('nationalist', 'pakistan'): 0,
 ('nationalist', 'police'): 152,
 ('nationalist', 'puja'): 0,
 ('nationalist', 'rape'): 33,
 ('nationalist', 'shibir'): 0,
 ('nationalist', 'vandalism'): 4,
 ('opposition', 'pakistan'): 0,
 ('opposition', 'police'): 1326,
 ('opposition', 'puja'): 0,
 ('opposition', 'rape'): 126,
 ('opposition', 'shibir'): 1,
 ('opposition', 'vandalism'): 78,
 ('pakistan', 'police'): 0,
 ('pakistan', 'puja'): 0,
 ('pakistan', 'rape'): 0,
 ('pakistan', 'shibir'): 0,
 ('pakistan', 'vandalism'): 0,
 ('police', 'puja'): 44,
 ('police', 'rape'): 966,
 ('police', 'shibir'): 15,
 ('police', 'vandalism'): 258,
 ('puja', 'rape'): 2,
 ('puja', 'shibir'): 0,
 ('puja', 'vandalism'): 4,
 ('rape', 'shibir'): 1,
 ('rape', 'vandalism'): 9,
 ('shibir', 'vandalism'): 2}

# %%
G = nx.Graph()

for key, value in all_combos_dict.items():
    G.add_edge(key[0], key[1], weight=value)

edges = G.edges()
weights = [G[u][v]['weight'] for u, v in edges]
weights_divideby1540 = [i / 1540 for i in weights]
weights_logE = [math.log(i) for i in weights if i != 0]
weights_log10 = [math.log10(i) for i in weights if i != 0]
weights_log1p = [math.log1p(i) for i in weights if i != 0]
weights_log2 = [math.log2(i) for i in weights if i != 0]

# %%
labels = G.nodes()

# %%
nx.draw(G, edges=edges, width=weights_divideby1540, with_labels=True, font_color="purple", font_weight=3)
plt.show()
# Out:
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/shoumik/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
nx.draw(G, edges=edges, width=weights_logE, with_labels=True, font_color="purple", font_weight=3)
plt.show()
# Out:
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/shoumik/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
nx.draw(G, edges=edges, width=weights_log10, with_labels=True, font_color="purple", font_weight=3)
plt.show()
# Out:
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/shoumik/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
nx.draw(G, edges=edges, width=weights_log1p, with_labels=True, font_color="purple", font_weight=3)
plt.show()
# Out:
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/shoumik/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
nx.draw(G, edges=edges, width=weights_log2, with_labels=True, font_color="purple", font_weight=3)
plt.show()
# Out:
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/shoumik/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
from sklearn import preprocessing

# %%
weights_scaled = preprocessing.scale(weights)

# %%
nx.draw(G, edges=edges, width=weights_scaled, with_labels=True, font_color="purple", font_weight=3)
plt.show()
# Out:
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/shoumik/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/shoumik/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...
